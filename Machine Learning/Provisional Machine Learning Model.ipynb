# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy as sp
from scipy import stats
from pathlib import Path
from collections import Counter

# %%
# Connecting the database

# Allows user input for the Postgres pass, so it doesn't need to be stored in another file
dbpass = input("Type password: ")

db_string = f"postgresql://postgres:{dbpass}@127.0.0.1:5432/Group6"
engine = create_engine(db_string)

movies_clean_df.to_sql(name='Movies', con=engine)
raw_oscars_df.to_sql(name='Oscars', con=engine)
# Out:
#      budget               original_title  popularity release_date  \
# 0  30000000                    Toy Story   21.946943   10/30/1995
# 1  65000000                      Jumanji   17.015539   12/15/1995
# 2         0             Grumpier Old Men   11.712900   12/22/1995
# 3  16000000            Waiting to Exhale    3.859495   12/22/1995
# 4         0  Father of the Bride Part II    8.387519    2/10/1995
# 5  60000000                         Heat   17.924927   12/15/1995
# 6  58000000                      Sabrina    6.677277   12/15/1995
# 7         0                 Tom and Huck    2.561161   12/22/1995
# 8  35000000                 Sudden Death    5.231580   12/22/1995
# 9  58000000                    GoldenEye   14.686036   11/16/1995
#
#        revenue  runtime    status                        title  vote_average  \
# 0  373554033.0     81.0  Released                    Toy Story           7.7
# 1  262797249.0    104.0  Released                      Jumanji           6.9
# ...

# %%
# dropping unecessary dependent variables and columns  
X = df.drop(columns=["popularity", "status", "release_date","vote_average", "vote_count", "original_title", "nominated"])

#create dummy columnn
obj_columns = ["genres"]
X = pd.get_dummies(X, obj_columns)

# %%
y = df["nominated"].to_frame()
